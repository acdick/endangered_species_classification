# %% [markdown]
# # U.S. Forest Service

# %%
import pandas as pd

# %% [markdown]
# ### Data Gathering

# %%
# 2018 national forest acreage by state (50 records, 3 columns)
forests = pd.read_csv('../Data/US_Forest_Service.csv')
print(forests.shape)
forests.head(50)
# Out:
# (50, 3)
#    State  Total Land Area (Thousands of Acres)  \
# 0     CT                                  3099
# 1     DE                                  1247
# 2     IL                                 35532
# 3     IN                                 22929
# 4     IA                                 35749
# 5     KS                                 52326
# 6     ME                                 19739
# 7     MD                                  6252
# 8     MA                                  4992
# 9     MI                                 36185
# 10    MN                                 50961
# 11    MO                                 43995
# 12    NE                                 49167
# 13    NH                                  5730
# 14    NJ                                  4707
# 15    NY                                 30161
# 16    ND                                 44161
# 17    OH                                 26151
# 18    PA                                 28635
# ...

# %%
forests.groupby(['State']).sum().sum()
# Out:
# Total Land Area (Thousands of Acres)     2260955
# Forest Land Area (Thousands of Acres)     818816
# dtype: int64

# %% [markdown]
# ### Data Loading

# %%
forests.to_pickle("../Data/FS.pkl")
