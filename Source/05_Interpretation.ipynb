# %% [markdown]
# # Intepretation

# %%
from config import plotly_id, plotly_key

import pandas as pd
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

# %%
plotly.tools.set_credentials_file(username=plotly_id, api_key=plotly_key)

# %%
models = pd.read_pickle("../Data/models.pkl")
#baseline = pd.read_pickle("../Data/baseline.pkl")
#balanced = pd.read_pickle("../Data/balanced.pkl")
#tuned = pd.read_pickle("../Data/tuned.pkl")

# %%
models
# Out:
#                   Model  Split  Accuracy  Precision    Recall  F1 Score  \
# 0                 Dummy  Train  0.772180   0.596262  0.772180  0.672914
# 1                 Dummy   Test  0.762351   0.581179  0.762351  0.659550
# 2   Logistic Regression  Train  0.810629   0.782781  0.810629  0.767842
# 3   Logistic Regression   Test  0.802385   0.779949  0.802385  0.758077
# 4   K Nearest Neighbors  Train  0.816913   0.796144  0.816913  0.797153
# 5   K Nearest Neighbors   Test  0.787053   0.753712  0.787053  0.763015
# 6         Decision Tree  Train  0.841943   0.829380  0.841943  0.821069
# 7         Decision Tree   Test  0.801959   0.763553  0.801959  0.770109
# 8         Random Forest  Train  0.772180   0.596262  0.772180  0.672914
# 9         Random Forest   Test  0.762351   0.581179  0.762351  0.659550
# 10                Dummy  Train  0.333333   0.111111  0.333333  0.166667
# 11                Dummy   Test  0.170784   0.029167  0.170784  0.049825
# 12  Logistic Regression  Train  0.647402   0.665346  0.647402  0.638062
# 13  Logistic Regression   Test  0.768739   0.752978  0.768739  0.753998
# 14  K Nearest Neighbors  Train  0.675034   0.700682  0.675034  0.663448
# 15  K Nearest Neighbors   Test  0.790034   0.757336  0.790034  0.766361
# 16        Decision Tree  Train  0.805563   0.812004  0.805563  0.805968
# 17        Decision Tree   Test  0.739353   0.777556  0.739353  0.753994
# 18        Random Forest  Train  0.594299   0.609299  0.594299  0.590456
# 19        Random Forest   Test  0.649489   0.784705  0.649489  0.699352
#
#     Configuration
# 0        Baseline
# 1        Baseline
# 2        Baseline
# 3        Baseline
# 4        Baseline
# 5        Baseline
# 6        Baseline
# 7        Baseline
# 8        Baseline
# 9        Baseline
# 10  Class Balance
# 11  Class Balance
# 12  Class Balance
# 13  Class Balance
# 14  Class Balance
# 15  Class Balance
# 16  Class Balance
# 17  Class Balance
# 18  Class Balance
# 19  Class Balance

# %%
#plotly
hover_text = []
color_range = []

#for index, row in models.iterrows():
#    hover_text.append(('Model: {model}<br>'+
#                      'Split: {split}').format(model=row['Model'],
#                                               split=row['Split']))
#    color_range.append(min(row['Dogs per Store'],120))

trace0 = go.Scatter(
    x=models['F1 Score'],
    y=models['Accuracy'],
#    text=hover_text,
    mode='markers',
    marker=dict(
#        size=bcg_matrix['Stores'],
#        color=color_range,
        showscale=True,
        reversescale=True,
        colorbar=dict(
                title='Dogs Per Store'
            ),
        colorscale='RdBu'
    )
)

data = [trace0]
layout = go.Layout(
    title='Tuned Model Hyper-Parameters for Endangered and Threatened Species',
    xaxis=dict(
        title='Number of Model Features',
        gridcolor='rgb(255, 255, 255)',
        zerolinewidth=1,
        ticklen=5,
        gridwidth=2,
    ),
    yaxis=dict(
        title='Model Performance Metric [F1 Score]',
        gridcolor='rgb(255, 255, 255)',
        zerolinewidth=1,
        ticklen=5,
        gridwidth=2,
    ),
    paper_bgcolor='rgb(243, 243, 243)',
    plot_bgcolor='rgb(243, 243, 243)',
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='endangered-species')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~adam.c.dick/4.embed" height="525px" width="100%"></iframe>
