# %% [markdown]
# # National Park Service

# %%
import pandas as pd
import missingno as msno

# %% [markdown]
# ### Data Gathering

# %%
# Acreage
acreage_2018 = pd.read_excel('../Data/NPS-Acreage-12-31-2018.xlsx', header=1)
print(acreage_2018.shape)
acreage_2018.head(50)
# Out:
# (430, 11)
#                        Area Name        State Region  NPS Fee Acres  \
# 0          A LINCOLN BIRTHPL NHP           KY    SER         344.50
# 1                      ACADIA NP           ME    NER       37438.18
# 2                      ADAMS NHP           MA    NER           9.17
# 3       AFRICAN BURIAL GROUND NM           NY    NER           0.35
# 4           AGATE FOSSIL BEDS NM           NE    MWR        2270.33
# 5               ALAGNAK WILD RVR           AK    AKR       26417.85
# 6      ALIBATES FLINT QUARRIES N           TX    IMR        1079.23
# 7         ALLEGHENY PRTGE RR NHS           PA    NER        1255.02
# 8                    AMISTAD NRA           TX    IMR       57292.44
# 9              ANDERSONVILLE NHS           GA    SER         499.88
# 10            ANDREW JOHNSON NHS           TN    SER          16.68
# 11          ANIAKCHAK N PRESERVE           AK    AKR      458809.35
# 12                  ANIAKCHAK NM           AK    AKR      137176.00
# ...

# %%
# Acreage
acreage_2013 = pd.read_excel('../Data/NPS-Acreage-12-31-2013.xlsx', header=1)
print(acreage_2013.shape)
acreage_2013.head(50)
# Out:
# (414, 11)
#                     Area Name        State Region  NPS Fee Acres  \
# 0       A LINCOLN BIRTHPL NHP           KY     SE         344.50
# 1                   ACADIA NP           ME     NE       35763.18
# 2                   ADAMS NHP           MA     NE           9.17
# 3    AFRICAN BURIAL GROUND NM           NY     NE           0.35
# 4        AGATE FOSSIL BEDS NM           NE     MW        2270.33
# 5            ALAGNAK WILD RVR           AK      A       26417.85
# 6   ALIBATES FLINT QUARRIES N           TX     IM        1079.23
# 7      ALLEGHENY PRTGE RR NHS           PA     NE        1255.02
# 8                 AMISTAD NRA           TX     IM       57292.44
# 9           ANDERSONVILLE NHS           GA     SE         499.88
# 10         ANDREW JOHNSON NHS           TN     SE          16.68
# 11       ANIAKCHAK N PRESERVE           AK      A      458809.35
# 12               ANIAKCHAK NM           AK      A      137176.00
# ...
